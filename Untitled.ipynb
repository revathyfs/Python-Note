# %%
x=3
y=4
print("The values are x =",x,"y=",y)
# Out:
# The values are x = 3 y= 4

# %%
print(f"THe values are x = {x}, y = {y}")
# Out:
# THe values are x = 3, y = 4

# %%
u=input("Enter the value :")
if bool(u):
    print("Something entered")
else:
    print("No Entry")
# Out:
# Enter the value : j[
# Something entered

# %%
s="Godislove"

# %%
len(s)
# Out:
# 9

# %%
s[::]
# Out:
# 'Godislove'

# %%
s[0:9]
# Out:
# 'Godislove'

# %%
s[:5]
# Out:
# 'Godis'

# %%
s[0:5]
# Out:
# 'Godis'

# %%
s[5:9]
# Out:
# 'love'

# %%
s[5:]
# Out:
# 'love'

# %%
s[-5:-1]
# Out:
# 'slov'

# %%
s[-5:]
# Out:
# 'slove'

# %%
s[-1]
# Out:
# 'e'

# %%
s[::]
# Out:
# 'Godislove'

# %%
s[::-1]

# %%
x="Python"
y="aeiou"
c=['*' if i in y else i for i in x]
