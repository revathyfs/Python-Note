# %%
a=[1,2,3,4,5]
s=[x*x for x in a]
print(s)
# Out:
# [1, 4, 9, 16, 25]

# %%
a=[1,2,3,4,5]
s=[]
for x in a:
    b=x*x
    s.append(b)
print(s)
# Out:
# [1, 4, 9, 16, 25]

# %%
n=[1,2,3,4,5]
s=[]

for i in n:
    s.append(i*i)
print(n)
print(s)
# Out:
# [1, 2, 3, 4, 5]
# [1, 4, 9, 16, 25]

# %%
n=[1,2,3,4,5]
s=list(map(lambda i:i*i,n))
print(n)
print(s)
# Out:
# [1, 2, 3, 4, 5]
# [1, 4, 9, 16, 25]

# %%
x=open('words.txt','r').read()
print(x)
# Out:
# world
# hello
# python

# %%
x=open('words.txt','w')
x.write("hello world")
x.close()

# %%
x=open('words.txt','r').read()
print(x)
# Out:
# hello world

# %%
x=open('words.txt','a')
x.write("\n This is python world")
x.close()

# %%
x=open('words.txt','r').read()
print(x)
# Out:
# hello world
#  This is python world
